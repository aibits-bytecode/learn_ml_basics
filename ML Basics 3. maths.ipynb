# %% [markdown]
# ### Mean squared error

# %% [markdown]
# ![Screenshot%202023-04-16%20at%2008.24.14.png](attachment:Screenshot%202023-04-16%20at%2008.24.14.png)

# %% [markdown]
# ![Screenshot%202023-04-15%20at%2017.05.22.png](attachment:Screenshot%202023-04-15%20at%2017.05.22.png)

# %% [markdown]
# ![Screenshot%202023-04-16%20at%2008.25.37.png](attachment:Screenshot%202023-04-16%20at%2008.25.37.png)

# %% [markdown]
# 1. So we take the less mean squared error witch gives best fit line

# %% [markdown]
# ### How we use Grdient descent

# %% [markdown]
# ![Screenshot%202023-04-15%20at%2017.19.41.png](attachment:Screenshot%202023-04-15%20at%2017.19.41.png)

# %% [markdown]
# ![Screenshot%202023-04-16%20at%2008.39.31.png](attachment:Screenshot%202023-04-16%20at%2008.39.31.png)

# %% [markdown]
# ![Screenshot%202023-04-16%20at%2008.40.24.png](attachment:Screenshot%202023-04-16%20at%2008.40.24.png)

# %% [markdown]
# When we change the m and b for y = mx+b we can see if the mse is increasing or decreasing
# So for a particuler position it gives the minimus mse

# %% [markdown]
# #### Creation of gradient descent

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
def gradient_descent(x, y):
    m_curr, b_curr = [0,0]
    iterations = 1000
    n = len(x)
    learning_rate = 0.08 
    for i in range(iterations):
        y_pred = m_curr * x + b_curr
        plt.plot(x,y_pred,color='g')
        cost = (1/n)*sum((y-y_pred)**2)
        md = -(2 / n) * sum(x * (y - y_pred))
        bd = -(2 / n) * sum(y - y_pred)
        m_curr = m_curr - learning_rate * md
        b_curr = b_curr - learning_rate * bd
        print("m {}, b {}, cost {}, iteration {}".format(m_curr, b_curr, cost, i))

# %%
x = np.array([1, 2, 3, 4, 5])
y = np.array([5, 7, 9, 11, 13])
# y = 2x+3
gradient_descent(x, y)
# Out:
# m 4.96, b 1.44, cost 89.0, iteration 0
# m 0.4991999999999983, b 0.26879999999999993, cost 71.10560000000002, iteration 1
# m 4.451584000000002, b 1.426176000000001, cost 56.8297702400001, iteration 2
# m 0.892231679999997, b 0.5012275199999995, cost 45.43965675929613, iteration 3
# m 4.041314713600002, b 1.432759910400001, cost 36.35088701894832, iteration 4
# m 1.2008760606719973, b 0.7036872622079998, cost 29.097483330142282, iteration 5
# m 3.7095643080294423, b 1.4546767911321612, cost 23.307872849944438, iteration 6
# m 1.4424862661541864, b 0.881337636696883, cost 18.685758762535738, iteration 7
# m 3.4406683721083144, b 1.4879302070713722, cost 14.994867596913156, iteration 8
# m 1.6308855378034224, b 1.0383405553279617, cost 12.046787238456794, iteration 9
# m 3.2221235247119777, b 1.5293810083298451, cost 9.691269350698109, iteration 10
# m 1.7770832372205707, b 1.1780607551353204, cost 7.8084968312098315, iteration 11
# ...
