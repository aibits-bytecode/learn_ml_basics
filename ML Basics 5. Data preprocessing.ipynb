# %% [markdown]
# Data gathering

# %%
import pandas as pd
df =pd.read_csv('data/homeprices 3.csv')
df.head()
# Out:
#               town  area   price
# 0  monroe township  2600  550000
# 1  monroe township  3000  565000
# 2  monroe township  3200  610000
# 3  monroe township  3600  680000
# 4  monroe township  4000  725000

# %% [markdown]
# * In here we can see we have string variable
# * if we replace these like 1,2,3 then model is going to think monroe is greater than other town etc

# %% [markdown]
# ![Screenshot%202023-04-16%20at%2012.37.20.png](attachment:Screenshot%202023-04-16%20at%2012.37.20.png)

# %% [markdown]
# What we can do for this

# %% [markdown]
# ![Screenshot%202023-04-16%20at%2012.40.07.png](attachment:Screenshot%202023-04-16%20at%2012.40.07.png)

# %% [markdown]
# ![Screenshot%202023-04-16%20at%2012.43.36.png](attachment:Screenshot%202023-04-16%20at%2012.43.36.png)

# %% [markdown]
# How to go on fire

# %%
df.head()
# Out:
#               town  area   price
# 0  monroe township  2600  550000
# 1  monroe township  3000  565000
# 2  monroe township  3200  610000
# 3  monroe township  3600  680000
# 4  monroe township  4000  725000

# %% [markdown]
# Creating the dummies

# %%
dummies = pd.get_dummies(df.town)
dummies
# Out:
#     monroe township  robinsville  west windsor
# 0                 1            0             0
# 1                 1            0             0
# 2                 1            0             0
# 3                 1            0             0
# 4                 1            0             0
# 5                 0            0             1
# 6                 0            0             1
# 7                 0            0             1
# 8                 0            0             1
# 9                 0            1             0
# 10                0            1             0
# 11                0            1             0
# 12                0            1             0

# %%
merged = pd.concat([df,dummies],axis='columns')
merged
# Out:
#                town  area   price  monroe township  robinsville  west windsor
# 0   monroe township  2600  550000                1            0             0
# 1   monroe township  3000  565000                1            0             0
# 2   monroe township  3200  610000                1            0             0
# 3   monroe township  3600  680000                1            0             0
# 4   monroe township  4000  725000                1            0             0
# 5      west windsor  2600  585000                0            0             1
# 6      west windsor  2800  615000                0            0             1
# 7      west windsor  3300  650000                0            0             1
# 8      west windsor  3600  710000                0            0             1
# 9       robinsville  2600  575000                0            1             0
# 10      robinsville  2900  600000                0            1             0
# ...

# %% [markdown]
# Drop the unwanted columns

# %%
df_modified = merged.drop(columns=['town','west windsor'])
df_modified
# Out:
#     area   price  monroe township  robinsville
# 0   2600  550000                1            0
# 1   3000  565000                1            0
# 2   3200  610000                1            0
# 3   3600  680000                1            0
# 4   4000  725000                1            0
# 5   2600  585000                0            0
# 6   2800  615000                0            0
# 7   3300  650000                0            0
# 8   3600  710000                0            0
# 9   2600  575000                0            1
# 10  2900  600000                0            1
# 11  3100  620000                0            1
# 12  3600  695000                0            1

# %% [markdown]
# Creating the model

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
x = df_modified[['area','monroe township','robinsville']]
x
# Out:
#     area  monroe township  robinsville
# 0   2600                1            0
# 1   3000                1            0
# 2   3200                1            0
# 3   3600                1            0
# 4   4000                1            0
# 5   2600                0            0
# 6   2800                0            0
# 7   3300                0            0
# 8   3600                0            0
# 9   2600                0            1
# 10  2900                0            1
# 11  3100                0            1
# 12  3600                0            1

# %%
y = df_modified[['price']]
y
# Out:
#      price
# 0   550000
# 1   565000
# 2   610000
# 3   680000
# 4   725000
# 5   585000
# 6   615000
# 7   650000
# 8   710000
# 9   575000
# 10  600000
# 11  620000
# 12  695000

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %% [markdown]
# Get the model score

# %%
model.score(x,y)
# Out:
# 0.9573929037221873

# %% [markdown]
# =============================================================================

# %% [markdown]
# <h2 style='color:purple'>Using sklearn OneHotEncoder</h2>

# %% [markdown]
# 1. We need to do label encoding

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
dfle = df
dfle.town = le.fit_transform(dfle.town)
dfle
# Out:
#     town  area   price
# 0      0  2600  550000
# 1      0  3000  565000
# 2      0  3200  610000
# 3      0  3600  680000
# 4      0  4000  725000
# 5      2  2600  585000
# 6      2  2800  615000
# 7      2  3300  650000
# 8      2  3600  710000
# 9      1  2600  575000
# 10     1  2900  600000
# 11     1  3100  620000
# 12     1  3600  695000

# %%
x = dfle[['town','area']]
x
# Out:
#     town  area
# 0      0  2600
# 1      0  3000
# 2      0  3200
# 3      0  3600
# 4      0  4000
# 5      2  2600
# 6      2  2800
# 7      2  3300
# 8      2  3600
# 9      1  2600
# 10     1  2900
# 11     1  3100
# 12     1  3600

# %%
y = dfle.price
y
# Out:
# 0     550000
# 1     565000
# 2     610000
# 3     680000
# 4     725000
# 5     585000
# 6     615000
# 7     650000
# 8     710000
# 9     575000
# 10    600000
# 11    620000
# 12    695000
# Name: price, dtype: int64

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
ct = ColumnTransformer([('town', OneHotEncoder(), [0])], remainder = 'passthrough')

# %%
x = ct.fit_transform(x)
x
# Out:
# array([[1.0e+00, 0.0e+00, 0.0e+00, 2.6e+03],
#        [1.0e+00, 0.0e+00, 0.0e+00, 3.0e+03],
#        [1.0e+00, 0.0e+00, 0.0e+00, 3.2e+03],
#        [1.0e+00, 0.0e+00, 0.0e+00, 3.6e+03],
#        [1.0e+00, 0.0e+00, 0.0e+00, 4.0e+03],
#        [0.0e+00, 0.0e+00, 1.0e+00, 2.6e+03],
#        [0.0e+00, 0.0e+00, 1.0e+00, 2.8e+03],
#        [0.0e+00, 0.0e+00, 1.0e+00, 3.3e+03],
#        [0.0e+00, 0.0e+00, 1.0e+00, 3.6e+03],
#        [0.0e+00, 1.0e+00, 0.0e+00, 2.6e+03],
#        [0.0e+00, 1.0e+00, 0.0e+00, 2.9e+03],
#        [0.0e+00, 1.0e+00, 0.0e+00, 3.1e+03],
#        [0.0e+00, 1.0e+00, 0.0e+00, 3.6e+03]])

# %%
x = x[:,1:]
x
# Out:
# array([[0.0e+00, 0.0e+00, 2.6e+03],
#        [0.0e+00, 0.0e+00, 3.0e+03],
#        [0.0e+00, 0.0e+00, 3.2e+03],
#        [0.0e+00, 0.0e+00, 3.6e+03],
#        [0.0e+00, 0.0e+00, 4.0e+03],
#        [0.0e+00, 1.0e+00, 2.6e+03],
#        [0.0e+00, 1.0e+00, 2.8e+03],
#        [0.0e+00, 1.0e+00, 3.3e+03],
#        [0.0e+00, 1.0e+00, 3.6e+03],
#        [1.0e+00, 0.0e+00, 2.6e+03],
#        [1.0e+00, 0.0e+00, 2.9e+03],
#        [1.0e+00, 0.0e+00, 3.1e+03],
#        [1.0e+00, 0.0e+00, 3.6e+03]])

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.predict([[0,1,3400]]) # 3400 sqr ft home in west windsor
# Out:
# array([681241.6684584])

# %%
model.predict([[1,0,2800]]) # 2800 sqr ft home in robbinsville
# Out:
# array([590775.63964739])

# %%
model.score(x,y)
# Out:
# 0.9573929037221872
