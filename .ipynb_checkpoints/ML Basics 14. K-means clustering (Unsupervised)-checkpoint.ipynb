# %% [markdown]
# ![Screenshot%202023-04-25%20at%2014.25.49.png](attachment:Screenshot%202023-04-25%20at%2014.25.49.png)

# %% [markdown]
# Good K number is the elbow in here it is 4

# %%
import pandas as pd
df = pd.read_csv('data/income.csv')
df.head()
# Out:
#       Name  Age  Income($)
# 0      Rob   27      70000
# 1  Michael   29      90000
# 2    Mohan   29      61000
# 3   Ismail   28      60000
# 4     Kory   42     150000
