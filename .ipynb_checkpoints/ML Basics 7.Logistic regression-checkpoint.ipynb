# %% [markdown]
# ![Screenshot%202023-04-16%20at%2017.51.24.png](attachment:Screenshot%202023-04-16%20at%2017.51.24.png)

# %% [markdown]
# We are using logistic regression to predict classification problems

# %% [markdown]
# ![Screenshot%202023-04-16%20at%2017.52.39.png](attachment:Screenshot%202023-04-16%20at%2017.52.39.png)

# %% [markdown]
# ![Screenshot%202023-04-16%20at%2017.59.27.png](attachment:Screenshot%202023-04-16%20at%2017.59.27.png)

# %% [markdown]
# Lets work on it 😇

# %%
import pandas as pd
df = pd.read_csv('data/insurance_data.csv')
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
import matplotlib.pyplot as plt
plt.scatter(df.age,df.bought_insurance, color='r')

# %%
x = df[['age']]
y = df['bought_insurance']

# %%
x
# Out:
#     age
# 0    22
# 1    25
# 2    47
# 3    52
# 4    46
# 5    56
# 6    55
# 7    60
# 8    62
# 9    61
# 10   18
# 11   28
# 12   27
# 13   29
# 14   49
# 15   55
# 16   25
# 17   58
# 18   19
# 19   18
# 20   21
# 21   26
# 22   40
# 23   45
# 24   50
# 25   54
# 26   23

# %%
y
# Out:
# 0     0
# 1     0
# 2     1
# 3     0
# 4     1
# 5     1
# 6     0
# 7     1
# 8     1
# 9     1
# 10    0
# 11    0
# 12    0
# 13    0
# 14    1
# 15    1
# 16    1
# 17    1
# 18    0
# 19    0
# 20    0
# 21    0
# 22    1
# 23    1
# 24    1
# 25    1
# 26    0
# Name: bought_insurance, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
x_train
# Out:
#     age
# 18   19
# 11   28
# 6    55
# 8    62
# 22   40
# 1    25
# 17   58
# 20   21
# 12   27
# 7    60
# 13   29
# 3    52
# 23   45
# 21   26
# 4    46
# 10   18
# 19   18
# 16   25
# 5    56
# 0    22
# 2    47

# %%
x_test
# Out:
#     age
# 15   55
# 25   54
# 24   50
# 9    61
# 26   23
# 14   49

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
x_test
# Out:
#     age
# 15   55
# 25   54
# 24   50
# 9    61
# 26   23
# 14   49

# %%
lr.predict(x_test)
# Out:
# array([1, 1, 1, 1, 0, 1])

# %%
lr.score(x_test,y_test)
# Out:
# 1.0
